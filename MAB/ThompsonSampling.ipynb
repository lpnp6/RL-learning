# %%
from ThompsonSampling import ThompsonSampling
from MAB import BernoulliBandit
from utils import plot_results

# %%
Thompson_sampling = ThompsonSampling(BernoulliBandit(10))
Thompson_sampling.run(5000)
print(f"ThompsonSampling 累计懊悔为{Thompson_sampling.regret}")
plot_results([Thompson_sampling],["ThompsonSampling"])
# Out:
# ThompsonSampling 累计懊悔为68.77967433515019
